# %%
import asyncio
from huobi import subscribe

# %%
def btc_callback(data):
        print(data)

# %%
task = subscribe({
        'market.btcusdt.kline.1min': {
            'callback': btc_callback
        }})

# %%
asyncio.get_event_loop().run_until_complete(task)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-8ef0637a3870> in <module>()
# ----> 1 asyncio.get_event_loop().run_until_complete(task)
#
# ~/.conda/envs/axiom/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# ~/.conda/envs/axiom/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     407         self._check_closed()
#     408         if self.is_running():
# --> 409             raise RuntimeError('This event loop is already running')
#     410         if events._get_running_loop() is not None:
#     411             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580364235, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.55, 'low': 3907.55, 'high': 3907.6, 'amount': 0.1293, 'vol': 505.25213, 'count': 5}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580365970, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.59, 'low': 3907.55, 'high': 3907.6, 'amount': 0.2664, 'vol': 1040.984061, 'count': 8}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580365995, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.59, 'low': 3907.55, 'high': 3907.6, 'amount': 0.2701, 'vol': 1055.442144, 'count': 9}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580366142, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.59, 'low': 3907.55, 'high': 3907.6, 'amount': 0.288, 'vol': 1125.388005, 'count': 10}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580366272, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.59, 'low': 3907.55, 'high': 3907.6, 'amount': 0.3519, 'vol': 1375.083006, 'count': 11}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580367238, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.7119, 'vol': 6689.535079, 'count': 14}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580367691, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.7964, 'vol': 7019.734884, 'count': 15}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580369300, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.8079, 'vol': 7064.673319, 'count': 16}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580369670, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.8718, 'vol': 7314.37471, 'count': 17}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580369825, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.8734, 'vol': 7320.627014, 'count': 18}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580372935, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.59, 'low': 3907.55, 'high': 3907.69, 'amount': 1.9481, 'vol': 7612.529074, 'count': 27}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580373804, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.9491, 'vol': 7616.436764, 'count': 28}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580375803, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 1.9982, 'vol': 7808.304313, 'count': 31}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580377755, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 2.0364, 'vol': 7957.578071, 'count': 36}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580378498, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 2.0456, 'vol': 7993.528819, 'count': 39}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580378547, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.67, 'low': 3907.55, 'high': 3907.69, 'amount': 2.1156, 'vol': 8267.06592, 'count': 47}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580379446, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.67, 'low': 3907.55, 'high': 3907.69, 'amount': 2.1856, 'vol': 8540.602822, 'count': 51}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580379493, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 2.2239, 'vol': 8690.267349, 'count': 52}}
# {'ch': 'market.btcusdt.kline.1min', 'ts': 1550580379961, 'tick': {'id': 1550580360, 'open': 3907.6, 'close': 3907.69, 'low': 3907.55, 'high': 3907.69, 'amount': 2.4131, 'vol': 9429.602297, 'count': 54}}
